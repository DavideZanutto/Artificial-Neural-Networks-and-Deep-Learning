# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/Challenge2
# Out:
# /gdrive/My Drive/Challenge2

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
import logging
from sklearn.model_selection import train_test_split

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 40

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Exploration Data Analysis (EDA)
# #### Human Activity Recognition

# %% [markdown]
# Load and clean the dataset

# %%
cd training_dataset_homework2/
# Out:
# /gdrive/My Drive/Challenge2/training_dataset_homework2

# %%
x_train= np.load("x_train.npy")
y_train= np.load("y_train.npy")

# %%
x_train.shape
# Out:
# (2429, 36, 6)

# %%
y_train.shape
# Out:
# (2429,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, random_state=seed, test_size=.1)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((2186, 36, 6), (2186,), (243, 36, 6), (243,))

# %% [markdown]
# ### Preprocessing

# %%
# Map activities to integers
label_mapping = {
     "Wish": 0,
      "Another": 1,
"Comfortably": 2,
"Money": 3,
"Breathe":4,
 "Time":5,
 "Brain":6,
 "Echoes":7,
"Wearing":8,
"Sorrow":9,
"Hey":10,
 "Shine":11
}

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
x_train.shape, y_train.shape, y_test.shape, y_test.shape
# Out:
# ((2186, 36, 6), (2186, 12), (243, 12), (243, 12))

# %%
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 64
epochs = 200

# %%
def build_BiLSTM_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128, return_sequences=True))(input_layer)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128))(bilstm)
    dropout = tfkl.Dropout(.8, seed=seed)(bilstm)

    # Classifier
    classifier = tfkl.Dense(64, activation='relu')(dropout)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  bidirectional_18 (Bidirecti  (None, 36, 256)          138240
#  onal)
#
#  bidirectional_19 (Bidirecti  (None, 256)              394240
#  onal)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 64)                16448
#
#  dense_9 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 549,708
# Trainable params: 549,708
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 31/31 [==============================] - 20s 415ms/step - loss: 2.0813 - accuracy: 0.3183 - val_loss: 1.6096 - val_accuracy: 0.4932 - lr: 0.0010
# Epoch 2/200
# 31/31 [==============================] - 11s 363ms/step - loss: 1.6609 - accuracy: 0.4545 - val_loss: 1.4272 - val_accuracy: 0.5434 - lr: 0.0010
# Epoch 3/200
# 31/31 [==============================] - 11s 366ms/step - loss: 1.3952 - accuracy: 0.5119 - val_loss: 1.2987 - val_accuracy: 0.5616 - lr: 0.0010
# Epoch 4/200
# 31/31 [==============================] - 11s 366ms/step - loss: 1.2201 - accuracy: 0.5806 - val_loss: 1.2573 - val_accuracy: 0.6256 - lr: 0.0010
# Epoch 5/200
# 31/31 [==============================] - 11s 361ms/step - loss: 1.0846 - accuracy: 0.6390 - val_loss: 1.2249 - val_accuracy: 0.5434 - lr: 0.0010
# Epoch 6/200
# 31/31 [==============================] - 11s 355ms/step - loss: 1.0150 - accuracy: 0.6604 - val_loss: 1.1464 - val_accuracy: 0.6393 - lr: 0.0010
# Epoch 7/200
# 31/31 [==============================] - 11s 356ms/step - loss: 0.9558 - accuracy: 0.6853 - val_loss: 1.1574 - val_accuracy: 0.6393 - lr: 0.0010
# Epoch 8/200
# 31/31 [==============================] - 11s 359ms/step - loss: 0.9064 - accuracy: 0.6950 - val_loss: 1.2388 - val_accuracy: 0.6301 - lr: 0.0010
# Epoch 9/200
# 31/31 [==============================] - 11s 357ms/step - loss: 0.8466 - accuracy: 0.7158 - val_loss: 1.1318 - val_accuracy: 0.6347 - lr: 0.0010
# Epoch 10/200
# 31/31 [==============================] - 11s 357ms/step - loss: 0.7678 - accuracy: 0.7422 - val_loss: 1.2199 - val_accuracy: 0.6256 - lr: 0.0010
# Epoch 11/200
# 31/31 [==============================] - 11s 365ms/step - loss: 0.7063 - accuracy: 0.7631 - val_loss: 1.2451 - val_accuracy: 0.6027 - lr: 0.0010
# Epoch 12/200
# 31/31 [==============================] - 11s 361ms/step - loss: 0.6325 - accuracy: 0.7778 - val_loss: 1.2741 - val_accuracy: 0.5936 - lr: 5.0000e-04
# Epoch 13/200
# 31/31 [==============================] - 11s 355ms/step - loss: 0.6026 - accuracy: 0.8012 - val_loss: 1.2130 - val_accuracy: 0.6301 - lr: 5.0000e-04
# Epoch 14/200
# 31/31 [==============================] - 11s 356ms/step - loss: 0.5376 - accuracy: 0.8139 - val_loss: 1.2413 - val_accuracy: 0.6438 - lr: 5.0000e-04
# Epoch 15/200
# 31/31 [==============================] - 11s 359ms/step - loss: 0.5221 - accuracy: 0.8226 - val_loss: 1.3625 - val_accuracy: 0.6119 - lr: 5.0000e-04
# Epoch 16/200
# 31/31 [==============================] - 11s 364ms/step - loss: 0.4715 - accuracy: 0.8302 - val_loss: 1.2697 - val_accuracy: 0.6164 - lr: 5.0000e-04
# Epoch 17/200
# 31/31 [==============================] - 11s 365ms/step - loss: 0.4463 - accuracy: 0.8505 - val_loss: 1.3955 - val_accuracy: 0.6347 - lr: 5.0000e-04
# Epoch 18/200
# 31/31 [==============================] - 11s 360ms/step - loss: 0.4414 - accuracy: 0.8536 - val_loss: 1.3646 - val_accuracy: 0.6256 - lr: 5.0000e-04
# Epoch 19/200
# 31/31 [==============================] - 11s 358ms/step - loss: 0.3803 - accuracy: 0.8724 - val_loss: 1.4990 - val_accuracy: 0.6119 - lr: 5.0000e-04
# Epoch 20/200
# 31/31 [==============================] - 11s 355ms/step - loss: 0.3357 - accuracy: 0.8856 - val_loss: 1.4290 - val_accuracy: 0.6621 - lr: 2.5000e-04
# Epoch 21/200
# 31/31 [==============================] - 13s 423ms/step - loss: 0.3194 - accuracy: 0.8882 - val_loss: 1.4815 - val_accuracy: 0.6758 - lr: 2.5000e-04
# Epoch 22/200
# 31/31 [==============================] - 11s 355ms/step - loss: 0.2928 - accuracy: 0.9029 - val_loss: 1.5879 - val_accuracy: 0.6438 - lr: 2.5000e-04
# Epoch 23/200
# 31/31 [==============================] - 11s 356ms/step - loss: 0.2667 - accuracy: 0.9110 - val_loss: 1.6308 - val_accuracy: 0.6256 - lr: 2.5000e-04
# Epoch 24/200
# 31/31 [==============================] - 11s 359ms/step - loss: 0.2516 - accuracy: 0.9146 - val_loss: 1.5348 - val_accuracy: 0.6575 - lr: 2.5000e-04
# Epoch 25/200
# 31/31 [==============================] - 11s 371ms/step - loss: 0.2565 - accuracy: 0.9171 - val_loss: 1.6932 - val_accuracy: 0.6073 - lr: 2.5000e-04
# Epoch 26/200
# 31/31 [==============================] - 11s 358ms/step - loss: 0.2371 - accuracy: 0.9202 - val_loss: 1.7348 - val_accuracy: 0.6119 - lr: 2.5000e-04
# Epoch 27/200
# 31/31 [==============================] - 11s 358ms/step - loss: 0.1995 - accuracy: 0.9354 - val_loss: 1.7692 - val_accuracy: 0.6256 - lr: 1.2500e-04
# Epoch 28/200
# 31/31 [==============================] - 11s 362ms/step - loss: 0.1919 - accuracy: 0.9436 - val_loss: 1.7875 - val_accuracy: 0.6301 - lr: 1.2500e-04
# Epoch 29/200
# 31/31 [==============================] - 11s 362ms/step - loss: 0.1827 - accuracy: 0.9431 - val_loss: 1.7836 - val_accuracy: 0.6347 - lr: 1.2500e-04
# Epoch 30/200
# 31/31 [==============================] - 11s 356ms/step - loss: 0.1614 - accuracy: 0.9507 - val_loss: 1.8165 - val_accuracy: 0.6301 - lr: 1.2500e-04
# Epoch 31/200
# 31/31 [==============================] - 11s 356ms/step - loss: 0.1566 - accuracy: 0.9548 - val_loss: 1.8928 - val_accuracy: 0.6438 - lr: 1.2500e-04

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('BiLSTM22')
# model = tfk.models.load_model('BiLSTM')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_55_layer_call_fn, lstm_cell_55_layer_call_and_return_conditional_losses, lstm_cell_56_layer_call_fn, lstm_cell_56_layer_call_and_return_conditional_losses, lstm_cell_58_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.

# %%
# Predict the test set with the BiLSTM
predictions = model.predict(x_test)
predictions.shape
# Out:
# 8/8 [==============================] - 3s 77ms/step
# (243, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.6626
# Precision: 0.6177
# Recall: 0.5632
# F1: 0.5332
