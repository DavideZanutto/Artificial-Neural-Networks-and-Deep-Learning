# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/Colab Notebooks/ANNDl2Homework/
# Out:
# /gdrive/My Drive/Colab Notebooks/ANNDl2Homework

# %%
ls
# Out:
#  1DNN.ipynb                                     LSTM.ipynb
#  BiLSTM.ipynb                                   training_dataset_homework2/
# 'Copia di 7) Timeseries Classification.ipynb'

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Exploration Data Analysis (EDA)
# #### Human Activity Recognition

# %% [markdown]
# Load and clean the dataset

# %%
x_train= np.load("training_dataset_homework2/x_train.npy")
y_train= np.load("training_dataset_homework2/y_train.npy")

# %%
x_train.shape
# Out:
# (2429, 36, 6)

# %%
y_train.shape
# Out:
# (2429,)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Split, Encode and Normalize

# %%
# Map activities to integers
label_mapping = {
     "Wish": 0,
      "Another": 1,
"Comfortably": 2,
"Money": 3,
"Breathe":4,
 "Time":5,
 "Brain":6,
 "Echoes":7,
"Wearing":8,
"Sorrow":9,
"Hey":10,
 "Shine":11
}

# %%
x_mean = x_train.mean()
x_mean
# Out:
# 25.295960919260704

# %%
x_std = x_train.std()
x_std
# Out:
# 658.4301638513654

# %%
# na merda
#x_train = (x_train - x_mean) / x_std

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, random_state=seed, test_size=.1)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((2186, 36, 6), (2186,), (243, 36, 6), (243,))

# %%
'''
# train
for i in range(x_train.shape[0]):
  transformer = RobustScaler().fit(x_train[i])
  x_train[i] = transformer.transform(x_train[i])

#test
for i in range(x_test.shape[0]):
  transformer = RobustScaler().fit(x_test[i])
  x_test[i] = transformer.transform(x_test[i])
'''
# Out:
# '\n# train\nfor i in range(x_train.shape[0]):\n  transformer = RobustScaler().fit(x_train[i])\n  x_train[i] = transformer.transform(x_train[i])\n\n#test\nfor i in range(x_test.shape[0]):\n  transformer = RobustScaler().fit(x_test[i])\n  x_test[i] = transformer.transform(x_test[i])\n'

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
x_train.shape, y_train.shape, y_test.shape, y_test.shape
# Out:
# ((2186, 36, 6), (2186, 12), (243, 12), (243, 12))

# %% [markdown]
# ### Build and train models

# %%
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 512
epochs = 200

# %% [markdown]
# #### Vanilla Long Short Term Memory (LSTM) Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=1FZ_P4SgVAA_mCZQ0tK18VwRqGqzNANOE
# )

# %%
def build_LSTM_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    lstm = tfkl.LSTM(128, return_sequences=True)(input_layer)
    lstm = tfkl.LSTM(128, return_sequences=True)(lstm)
    #dropout = tfkl.Dropout(.5, seed=seed)(lstm)
    lstm = tfkl.LSTM(128)(lstm)
    #dropout = tfkl.Dropout(.5, seed=seed)(lstm)

    # Classifier
    classifier = tfkl.Dense(128, activation='relu')(lstm)
    classifier = tfkl.BatchNormalization()(classifier)
    dropout = tfkl.Dropout(.4, seed=seed)(classifier)

    classifier = tfkl.Dense(128, activation='relu')(dropout)
    classifier = tfkl.BatchNormalization()(classifier)
    dropout = tfkl.Dropout(.4, seed=seed)(classifier)
    
    output_layer = tfkl.Dense(classes, activation='softmax')(dropout)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_LSTM_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  lstm (LSTM)                 (None, 36, 128)           69120
#
#  lstm_1 (LSTM)               (None, 36, 128)           131584
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 128)               16512
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 367,884
# Trainable params: 367,372
# Non-trainable params: 512
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-fcf8df7af210> in <module>
#       1 # Train the model
# ----> 2 history = model.fit(
#       3     x = x_train,
#       4     y = y_train,
#       5     batch_size = batch_size,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     978         # Lifting succeeded, so variables are initialized and we can run the
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#     982       _, _, filtered_flat_args = (
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('LSTM')
# model = tfk.models.load_model('LSTM')

# %%
# Predict the test set with the LSTM
predictions = model.predict(x_test)
predictions.shape

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %% [markdown]
# #### Bidirectional Long Short Term Memory (BiLSTM) Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=1CN-jJqzb5AurhnMMiuvdVCaPGy2KReLc
# )

# %%
def build_BiLSTM_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128, return_sequences=True))(input_layer)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128))(bilstm)
    dropout = tfkl.Dropout(.5, seed=seed)(bilstm)

    # Classifier
    classifier = tfkl.Dense(128, activation='relu')(dropout)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape, classes)
model.summary()

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('BiLSTM')
# model = tfk.models.load_model('BiLSTM')

# %%
# Predict the test set with the BiLSTM
predictions = model.predict(x_test)
predictions.shape

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %% [markdown]
# #### 1D Convolutional Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=10B7c-F58-eNr6CP7D_UZeVp0gTeYMrFQ
# )

# %%
def build_1DCNN_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn = tfkl.Conv1D(256,3,padding='same')(input_layer)
    #cnn = tfkl.BatchNormalization()(cnn)
    cnn = tfkl.LeakyReLU(alpha=0.2)(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn = tfkl.Conv1D(256,3,padding='same')(cnn)
    #cnn = tfkl.BatchNormalization()(cnn)
    cnn = tfkl.LeakyReLU(alpha=0.2)(cnn)
    gap = tfkl.GlobalAveragePooling1D()(cnn)
    dropout = tfkl.Dropout(.3, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(128)(dropout)
    classifier = tfkl.LeakyReLU(alpha=0.2)(classifier)
    classifier = tfkl.BatchNormalization()(classifier)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_1DCNN_classifier(input_shape, classes)
model.summary()

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('1DCNN')
# model = tfk.models.load_model('1DCNN')

# %%
# Predict the test set with the 1DCNN
predictions = model.predict(x_test)
predictions.shape

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %% [markdown]
# Damn, once again no free lunch

# %% [markdown]
# ### MIX

# %%
def build_mix_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    #1D
    cnn = tfkl.Conv1D(1024,3,padding='same')(input_layer)
    cnn = tfkl.LeakyReLU(alpha=0.2)(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(64,3,padding='same')(cnn)
    cnn = tfkl.LeakyReLU(alpha=0.2)(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    #gap = tfkl.GlobalAveragePooling1D()(cnn)
    #dropout = tfkl.Dropout(.5, seed=seed)(gap)

    # Classifier
    #classifier = tfkl.Dense(128, activation='relu')(dropout)

    #LSTM
    lstm = tfkl.LSTM(512, return_sequences=True)(cnn)
    #lstm = tfkl.LSTM(128, return_sequences=True)(cnn)
    lstm = tfkl.LSTM(256)(lstm)
    #dropout = tfkl.Dropout(.5, seed=seed)(lstm)

    # Classifier
    #classifier = tfkl.Dense(128, activation='relu')(dropout)

    # Classifier
    classifier = tfkl.Dense(1024)(lstm)
    classifier = tfkl.LeakyReLU(alpha=0.2)(classifier)
    classifier = tfkl.Dense(256)(classifier)
    classifier = tfkl.LeakyReLU(alpha=0.2)(classifier)
    classifier = tfkl.Dense(256)(classifier)
    classifier = tfkl.LeakyReLU(alpha=0.2)(classifier)
    dropout = tfkl.Dropout(.3, seed=seed)(classifier)

    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_mix_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d_16 (Conv1D)          (None, 36, 1024)          19456
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 36, 1024)          0
#
#  max_pooling1d_16 (MaxPoolin  (None, 18, 1024)         0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 18, 64)            196672
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 18, 64)            0
#
#  max_pooling1d_17 (MaxPoolin  (None, 9, 64)            0
#  g1D)
#
#  lstm_16 (LSTM)              (None, 9, 512)            1181696
#
#  lstm_17 (LSTM)              (None, 256)               787456
#
#  dense_32 (Dense)            (None, 1024)              263168
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 1024)              0
#
#  dense_33 (Dense)            (None, 256)               262400
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 256)               0
#
#  dense_34 (Dense)            (None, 256)               65792
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 256)               0
#
#  dense_35 (Dense)            (None, 12)                3084
#
# =================================================================
# Total params: 2,779,724
# Trainable params: 2,779,724
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 4/4 [==============================] - 4s 307ms/step - loss: 2.2561 - accuracy: 0.2445 - val_loss: 1.8979 - val_accuracy: 0.3927 - lr: 0.0010
# Epoch 2/200
# 4/4 [==============================] - 0s 53ms/step - loss: 1.8597 - accuracy: 0.3920 - val_loss: 1.6936 - val_accuracy: 0.4429 - lr: 0.0010
# Epoch 3/200
# 4/4 [==============================] - 0s 49ms/step - loss: 1.6565 - accuracy: 0.4474 - val_loss: 1.4365 - val_accuracy: 0.4795 - lr: 0.0010
# Epoch 4/200
# 4/4 [==============================] - 0s 49ms/step - loss: 1.4646 - accuracy: 0.4835 - val_loss: 1.2177 - val_accuracy: 0.5753 - lr: 0.0010
# Epoch 5/200
# 4/4 [==============================] - 0s 49ms/step - loss: 1.3072 - accuracy: 0.5343 - val_loss: 1.0914 - val_accuracy: 0.6027 - lr: 0.0010
# Epoch 6/200
# 4/4 [==============================] - 0s 53ms/step - loss: 1.1809 - accuracy: 0.5907 - val_loss: 1.0886 - val_accuracy: 0.6256 - lr: 0.0010
# Epoch 7/200
# 4/4 [==============================] - 0s 54ms/step - loss: 1.1282 - accuracy: 0.6157 - val_loss: 0.9795 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 8/200
# 4/4 [==============================] - 0s 46ms/step - loss: 1.0684 - accuracy: 0.6258 - val_loss: 1.0031 - val_accuracy: 0.6484 - lr: 0.0010
# Epoch 9/200
# 4/4 [==============================] - 0s 45ms/step - loss: 1.0001 - accuracy: 0.6497 - val_loss: 1.0254 - val_accuracy: 0.6621 - lr: 0.0010
# Epoch 10/200
# 4/4 [==============================] - 0s 49ms/step - loss: 0.9660 - accuracy: 0.6518 - val_loss: 0.9469 - val_accuracy: 0.6758 - lr: 0.0010
# Epoch 11/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.9596 - accuracy: 0.6746 - val_loss: 0.9516 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 12/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.8952 - accuracy: 0.6823 - val_loss: 0.9266 - val_accuracy: 0.6758 - lr: 0.0010
# Epoch 13/200
# 4/4 [==============================] - 0s 50ms/step - loss: 0.8364 - accuracy: 0.7016 - val_loss: 0.9744 - val_accuracy: 0.7078 - lr: 0.0010
# Epoch 14/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7809 - accuracy: 0.7239 - val_loss: 0.8784 - val_accuracy: 0.7032 - lr: 0.0010
# Epoch 15/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7638 - accuracy: 0.7255 - val_loss: 0.9573 - val_accuracy: 0.6712 - lr: 0.0010
# Epoch 16/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7252 - accuracy: 0.7412 - val_loss: 0.8706 - val_accuracy: 0.6986 - lr: 0.0010
# Epoch 17/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7143 - accuracy: 0.7412 - val_loss: 1.0492 - val_accuracy: 0.6484 - lr: 0.0010
# Epoch 18/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7205 - accuracy: 0.7295 - val_loss: 1.0392 - val_accuracy: 0.6849 - lr: 0.0010
# Epoch 19/200
# 4/4 [==============================] - 0s 51ms/step - loss: 0.6513 - accuracy: 0.7646 - val_loss: 0.8649 - val_accuracy: 0.7169 - lr: 5.0000e-04
# Epoch 20/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5731 - accuracy: 0.7997 - val_loss: 0.9352 - val_accuracy: 0.7169 - lr: 5.0000e-04
# Epoch 21/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5404 - accuracy: 0.8099 - val_loss: 0.9919 - val_accuracy: 0.6804 - lr: 5.0000e-04
# Epoch 22/200
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4902 - accuracy: 0.8271 - val_loss: 0.9238 - val_accuracy: 0.7397 - lr: 5.0000e-04
# Epoch 23/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.4393 - accuracy: 0.8546 - val_loss: 0.9555 - val_accuracy: 0.7306 - lr: 5.0000e-04
# Epoch 24/200
# 4/4 [==============================] - 0s 47ms/step - loss: 0.4201 - accuracy: 0.8571 - val_loss: 0.9752 - val_accuracy: 0.7260 - lr: 5.0000e-04
# Epoch 25/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3524 - accuracy: 0.8851 - val_loss: 1.0898 - val_accuracy: 0.7169 - lr: 5.0000e-04
# Epoch 26/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3257 - accuracy: 0.8973 - val_loss: 1.1260 - val_accuracy: 0.7169 - lr: 5.0000e-04
# Epoch 27/200
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2977 - accuracy: 0.9044 - val_loss: 1.1352 - val_accuracy: 0.7443 - lr: 5.0000e-04
# Epoch 28/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2400 - accuracy: 0.9304 - val_loss: 1.2324 - val_accuracy: 0.7306 - lr: 5.0000e-04
# Epoch 29/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2017 - accuracy: 0.9344 - val_loss: 1.2244 - val_accuracy: 0.7260 - lr: 5.0000e-04
# Epoch 30/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.2088 - accuracy: 0.9339 - val_loss: 1.2842 - val_accuracy: 0.7032 - lr: 5.0000e-04
# Epoch 31/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.2577 - accuracy: 0.9049 - val_loss: 1.5554 - val_accuracy: 0.6621 - lr: 5.0000e-04
# Epoch 32/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2302 - accuracy: 0.9192 - val_loss: 1.4948 - val_accuracy: 0.6621 - lr: 5.0000e-04
# Epoch 33/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1755 - accuracy: 0.9471 - val_loss: 1.3968 - val_accuracy: 0.7215 - lr: 2.5000e-04
# Epoch 34/200
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1474 - accuracy: 0.9507 - val_loss: 1.3904 - val_accuracy: 0.7397 - lr: 2.5000e-04
# Epoch 35/200
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1265 - accuracy: 0.9593 - val_loss: 1.4368 - val_accuracy: 0.6941 - lr: 2.5000e-04
# Epoch 36/200
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1138 - accuracy: 0.9695 - val_loss: 1.4348 - val_accuracy: 0.7215 - lr: 2.5000e-04
# Epoch 37/200
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0996 - accuracy: 0.9710 - val_loss: 1.5359 - val_accuracy: 0.7260 - lr: 2.5000e-04

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set with the 1DCNN
predictions = model.predict(x_test)
predictions.shape
# Out:
# 8/8 [==============================] - 1s 4ms/step
# (243, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.7366
# Precision: 0.6267
# Recall: 0.6232
# F1: 0.602
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#model.save('MIX')
# model = tfk.models.load_model('1DCNN')
